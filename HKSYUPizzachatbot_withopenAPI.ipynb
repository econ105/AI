# %%
import openai

# %%
import os

# %%
openai.api_key  = "insert your openAPI key here"

# %%
import panel

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context)
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))

    return pn.Column(*panels)

# %% [markdown]
# The function collect_messages takes an input parameter (denoted by _, which typically indicates that the parameter is not used within the function).
#
# The function performs the following steps:
#
#     It assigns the value of inp.value_input to the variable prompt. This suggests that inp is an object with an attribute named value_input that holds some user input.
#
#     It sets inp.value to an empty string, possibly clearing the user input field.
#
#     It appends a dictionary to the context list. This dictionary represents a message from the user and has two key-value pairs: 'role':'user' and 'content':f"{prompt}". The 'role' key indicates the role of the message, which is 'user' in this case. The 'content' key holds the content of the message, which is the value stored in prompt.
#
#     It calls the get_completion_from_messages function, passing in the context list as an argument. This function likely takes the conversation context and generates a response based on it. The result of this function call is assigned to the variable response.
#
#     It appends another dictionary to the context list. This dictionary represents a message from the assistant and has the same structure as the user message dictionary. The 'role' key is set to 'assistant', and the 'content' key is set to the value stored in response.
#
#     It creates two pn.Row objects, each containing a label (e.g., 'User:') and a pn.pane.Markdown object. The first row represents the user message, and the second row represents the assistant's response. The width parameter is set to 600, indicating the desired width of the Markdown content.
#
#     It appends the two pn.Row objects to the panels list.
#
#     Finally, it returns a pn.Column object containing all the elements in the panels list.
#
# Overall, the collect_messages function appears to be part of a larger program or application that collects user input, generates a response using a conversation context, and displays the conversation history using the pn library for creating interactive panels.

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # control the random level of output
    )
    return response.choices[0].message["content"]

def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, # control the random level of output
    )
#     print(str(response.choices[0].message))
    return response.choices[0].message["content"]

# %% [markdown]
# Certainly! The code snippet provided includes two functions: get_completion and get_completion_from_messages. Let's break down each function and explain their purpose and functionality.
#
#     get_completion(prompt, model="gpt-3.5-turbo"):
#         This function takes two parameters: prompt and model.
#         The prompt parameter represents the input text or message for which a completion or response needs to be generated.
#         The model parameter is optional and defaults to "gpt-3.5-turbo". It specifies the model to be used for generating the completion.
#         Inside the function, a list named messages is created. It contains a single dictionary representing a user message. The dictionary has two key-value pairs: 'role':'user' and 'content':prompt. This structure is consistent with the conversation format expected by the OpenAI API.
#         The function then calls openai.ChatCompletion.create() to generate a completion. It passes the specified model, messages, and a temperature value of 0. The temperature parameter controls the level of randomness in the generated output.
#         The API call returns a response object, which contains a list of choices. Each choice represents a possible completion or response.
#         The function returns the 'content' value of the first choice in the response object. This value represents the generated completion or response.
#
#     get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
#         This function takes three parameters: messages, model, and temperature.
#         The messages parameter is a list of message dictionaries representing the conversation history or context.
#         The model parameter is optional and defaults to "gpt-3.5-turbo". It specifies the model to be used for generating the completion.
#         The temperature parameter is also optional and defaults to 0. It controls the level of randomness in the generated output.
#         Inside the function, openai.ChatCompletion.create() is called with the specified model, messages, and temperature.
#         The API call returns a response object, which contains a list of choices representing possible completions or responses.
#         The function returns the 'content' value of the first choice in the response object. This value represents the generated completion or response.
#
# Both functions utilize the OpenAI GPT-3.5-turbo model to generate text completions based on the provided prompts or conversation history. The get_completion_from_messages function specifically allows passing a list of messages to generate a response that takes into account the conversation context.

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display

context = [{'role':'system', 'content':"""
You are a booking food robot in a pizza restaurant named HKSYU, your job is to serve the customers and record
the order information from guests. You should say hi to customers and wait them to reply what they need. Then
you need to confirm their orders with them, and ask them if they need anything else. Then, you should ask if they
eat here or take away, if they say they would like to take away, you should ask them their address. Finally, you need to
tell the customers the total price, and send your blessigs.
Please make sure all menus, size to make it very accurate to recognise the only one choice from menu.
Your reply should be brief, and very friendly.
The menu:(comes with price)
Pepperoni Pizza (large, medium, small) $12.95, $10.00, $7.00
Chesse Pizza (large, medium, small) $12.00, $8.00, $6.00
Fries (large, medium, small) $5.00, $4.00, $3.00
Salad (large, medium, small) $3.55, $3.00, $2.00

toppings:
Mushroom $1.00
BBQ Sauce: $0.50
Peppers: $0.2

Drinks:
Cola (large, medium, small) $2.85, $2.00, $1.50
Americano (large, medium, small) $3.20, $2.60, $2.00

"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='2242642e-0ff7-40fc-8e53-a3f8b003f683'>
#   <div id="bbe5d1ff-0b60-4da3-aa8d-89d030578e61" data-root-id="2242642e-0ff7-40fc-8e53-a3f8b003f683" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# The code snippet provided demonstrates the use of the panel library (imported as pn) for creating a graphical user interface (GUI). Let's break down the code and explain its functionality.
#
#     import panel as pn and pn.extension():
#         The code imports the panel library and then calls pn.extension() to initialize the panel extension. This step is necessary to enable the use of panel components.
#
#     panels = []:
#         This creates an empty list named panels. The purpose of this list is to collect display components that will be added to the GUI.
#
#     context:
#         This initializes a list named context with a single dictionary element. The dictionary represents a system message that provides instructions and information to the user. It has a 'role' key set to 'system' and a 'content' key that contains a multi-line string with detailed instructions for a food-ordering chatbot in a pizza restaurant.
#
#     inp and button_conversation:
#         The inp variable represents a TextInput widget from the panel library. It provides a text input field for the user to enter their messages or prompts.
#         The button_conversation variable represents a Button widget from the panel library. It serves as a button that triggers the conversation processing when clicked.
#
#     interactive_conversation:
#         This line binds the collect_messages function (presumably defined elsewhere) to the button_conversation widget. It means that when the button is clicked, the collect_messages function will be executed.
#
#     dashboard:
#         This creates a Column layout from the panel library, named dashboard.
#         The inp widget and a row containing the button_conversation widget are added to the dashboard column.
#         The interactive_conversation function (bound to button_conversation) is added as a panel to the dashboard column. The loading_indicator parameter is set to True, indicating that a loading indicator should be displayed while the conversation is being processed. The height parameter is set to 300, defining the height of the panel.
#
# Overall, the code sets up a GUI using the panel library. It includes an input field for the user to enter text messages, a button to trigger conversation processing, and a panel to display the conversation history and responses. The collect_messages function is bound to the button to handle the conversation logic.

# %%
dashboard
# Out:
# Column
#     [0] TextInput(placeholder='Enter text here…', value_input='large Pepperoni Pizza, ...)
#     [1] Row
#         [0] Button(clicks=3, name='Chat!')
#     [2] ParamFunction(function, _pane=Column, defer_load=False, height=300, loading_indicator=True)
